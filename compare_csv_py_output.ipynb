# %%
import pandas as pd
import subprocess

# GitHub raw CSV URL
csv_url = 'https://raw.githubusercontent.com/lebinho/biznesradar/main/biznesradar_stocks_parameters.csv'

# Step 1: Try running lista_spolek.py to get fresh data
try:
    print("Fetching fresh data from lista_spolek.py...")
    
    # Run lista_spolek.py and capture output
    result = subprocess.run(['python', 'lista_spolek.py'], check=True, capture_output=True, text=True)
    
    # Convert output into a DataFrame
    company_names = result.stdout.strip().split("\n")  # Split output into lines
    lista_spolek_www = pd.DataFrame(company_names, columns=["Stock Parameter"])
    
    print("Successfully retrieved fresh data from lista_spolek.py!")

except subprocess.CalledProcessError as e:
    print("Error running lista_spolek.py:", e)
    print("Skipping comparison.")
    exit()  # Exit the script if lista_spolek.py fails

# Step 2: Load the CSV from GitHub
print("Loading static data from CSV on GitHub...")
lista_spolek_csv = pd.read_csv(csv_url, sep=',')

# Step 3: Compare both DataFrames
print("\n🔍 Comparing results...")

# Find missing values
diff_www_not_in_csv = lista_spolek_www[~lista_spolek_www["Stock Parameter"].isin(lista_spolek_csv["Stock Parameter"])]
diff_csv_not_in_www = lista_spolek_csv[~lista_spolek_csv["Stock Parameter"].isin(lista_spolek_www["Stock Parameter"])]

# Print differences
print("\n✅ Stocks found in lista_spolek.py but NOT in CSV:")
print(diff_www_not_in_csv)

print("\n❌ Stocks found in CSV but NOT in lista_spolek.py:")
print(diff_csv_not_in_www)

# Check if both are identical
if diff_www_not_in_csv.empty and diff_csv_not_in_www.empty:
    print("\n🎉 Both datasets are identical!")
else:
    print("\n⚠️ There are differences between the live and static data.")
# Out:
# Fetching fresh data from lista_spolek.py...
# Successfully retrieved fresh data from lista_spolek.py!
# Loading static data from CSV on GitHub...
#
# 🔍 Comparing results...
#
# ✅ Stocks found in lista_spolek.py but NOT in CSV:
#      Stock Parameter
# 0      06N (06MAGNA)
# 1     08N (08OCTAVA)
# 2        11B (11BIT)
# 3         1AT (ATAL)
# 4      3RG (3RGAMES)
# ..               ...
# 409     ZAP (PULAWY)
# 410      ZEP (ZEPAK)
# 411      ZMT (ZAMET)
# 412      ZRE (ZREMB)
# 414  ZUK (STAPORKOW)
#
# [393 rows x 1 columns]
#
# ❌ Stocks found in CSV but NOT in lista_spolek.py:
#               Ticker Stock Parameter
# 0    01C (01CYBATON)     01CYBERATON
# 1      06N (06MAGNA)             06N
# 2     08N (08OCTAVA)          OCTAVA
# 3        11B (11BIT)  11-BIT-STUDIOS
# 4         1AT (ATAL)            ATAL
# ..               ...             ...
# 780      ZEP (ZEPAK)           ZEPAK
# 781      ZMT (ZAMET)  ZAMET-INDUSTRY
# 782      ZRE (ZREMB)  ZREMB-CHOJNICE
# 783    ZRX (ZORTRAX)             ZRX
# 785  ZUK (STAPORKOW)       STAPORKOW
#
# [764 rows x 2 columns]
#
# ⚠️ There are differences between the live and static data.

# %%
import pandas as pd
import subprocess

# GitHub raw CSV URL
csv_url = 'https://raw.githubusercontent.com/lebinho/biznesradar/main/biznesradar_stocks_parameters.csv'

# Step 1: Try running lista_spolek.py to get fresh data
try:
    print("Fetching fresh data from lista_spolek.py...")
    
    # Run lista_spolek.py and capture output
    result = subprocess.run(['python', 'lista_spolek.py'], check=True, capture_output=True, text=True)
    
    # Convert output into a DataFrame
    company_names = result.stdout.strip().split("\n")  # Split output into lines
    lista_spolek_www = pd.DataFrame(company_names, columns=["Stock Parameter"])

    print("Successfully retrieved fresh data from lista_spolek.py!")

except subprocess.CalledProcessError as e:
    print("Error running lista_spolek.py:", e)
    print("Skipping comparison.")
    exit()  # Exit the script if lista_spolek.py fails

# Step 2: Load the CSV from GitHub
print("Loading static data from CSV on GitHub...")
lista_spolek_csv = pd.read_csv(csv_url, sep=',')

# Step 3: Align columns (Check for missing columns)
print("\n🔍 Checking column differences...")

missing_in_csv = set(lista_spolek_www.columns) - set(lista_spolek_csv.columns)
missing_in_www = set(lista_spolek_csv.columns) - set(lista_spolek_www.columns)

if missing_in_csv:
    print(f"⚠️ Columns in `lista_spolek.py` output but NOT in CSV: {missing_in_csv}")

if missing_in_www:
    print(f"⚠️ Columns in CSV but NOT in `lista_spolek.py` output: {missing_in_www}")

# Ensure both have the same columns by adding missing columns with NaN
for col in missing_in_csv:
    lista_spolek_csv[col] = None  # Add missing columns to CSV

for col in missing_in_www:
    lista_spolek_www[col] = None  # Add missing columns to Web data

# Step 4: Merge data side by side
comparison_df = pd.concat([lista_spolek_csv.add_suffix('_CSV'), lista_spolek_www.add_suffix('_WWW')], axis=1)

# Display results
print("\n📝 Side-by-side comparison of stock data:")
print(comparison_df)

# Optional: Save to file for better readability
comparison_df.to_csv("comparison_output.csv", index=False)
print("\n📂 Comparison saved as 'comparison_output.csv'.")
# Out:
# Fetching fresh data from lista_spolek.py...
# Successfully retrieved fresh data from lista_spolek.py!
# Loading static data from CSV on GitHub...
#
# 🔍 Checking column differences...
# ⚠️ Columns in CSV but NOT in `lista_spolek.py` output: {'Ticker'}
#
# 📝 Side-by-side comparison of stock data:
#           Ticker_CSV Stock Parameter_CSV Stock Parameter_WWW Ticker_WWW
# 0    01C (01CYBATON)         01CYBERATON       06N (06MAGNA)       None
# 1      06N (06MAGNA)                 06N      08N (08OCTAVA)       None
# 2     08N (08OCTAVA)              OCTAVA         11B (11BIT)       None
# 3        11B (11BIT)      11-BIT-STUDIOS          1AT (ATAL)       None
# 4         1AT (ATAL)                ATAL       3RG (3RGAMES)       None
# ..               ...                 ...                 ...        ...
# 781      ZMT (ZAMET)      ZAMET-INDUSTRY                 NaN        NaN
# 782      ZRE (ZREMB)      ZREMB-CHOJNICE                 NaN        NaN
# 783    ZRX (ZORTRAX)                 ZRX                 NaN        NaN
# 784              ZUE                 ZUE                 NaN        NaN
# 785  ZUK (STAPORKOW)           STAPORKOW                 NaN        NaN
#
# [786 rows x 4 columns]
#
# 📂 Comparison saved as 'comparison_output.csv'.

# %% [markdown]
# with stats

# %%
import pandas as pd
import subprocess

# GitHub raw CSV URL
csv_url = 'https://raw.githubusercontent.com/lebinho/biznesradar/main/biznesradar_stocks_parameters.csv'

# Step 1: Try running lista_spolek.py to get fresh data
try:
    print("Fetching fresh data from lista_spolek.py...")
    
    # Run lista_spolek.py and capture output
    result = subprocess.run(['python', 'lista_spolek.py'], check=True, capture_output=True, text=True)
    
    # Convert output into a DataFrame
    company_names = result.stdout.strip().split("\n")  # Split output into lines
    lista_spolek_www = pd.DataFrame(company_names, columns=["Stock Parameter"])

    print("✅ Successfully retrieved fresh data from lista_spolek.py!")

except subprocess.CalledProcessError as e:
    print("❌ Error running lista_spolek.py:", e)
    print("Skipping comparison.")
    exit()  # Exit the script if lista_spolek.py fails

# Step 2: Load the CSV from GitHub
print("\n📥 Loading static data from CSV on GitHub...")
lista_spolek_csv = pd.read_csv(csv_url, sep=',')

# Step 3: Print dataset descriptions
print("\n📊 **Dataset Summary:**")
print(f"- 🖥️ `lista_spolek.py` output → Rows: {lista_spolek_www.shape[0]}, Columns: {lista_spolek_www.shape[1]}")
print(f"- 📄 CSV file from GitHub → Rows: {lista_spolek_csv.shape[0]}, Columns: {lista_spolek_csv.shape[1]}")

# Step 4: Align columns (Check for missing columns)
print("\n🔍 Checking column differences...")

missing_in_csv = set(lista_spolek_www.columns) - set(lista_spolek_csv.columns)
missing_in_www = set(lista_spolek_csv.columns) - set(lista_spolek_www.columns)

if missing_in_csv:
    print(f"⚠️ Columns in `lista_spolek.py` output but NOT in CSV: {missing_in_csv}")

if missing_in_www:
    print(f"⚠️ Columns in CSV but NOT in `lista_spolek.py` output: {missing_in_www}")

# Ensure both have the same columns by adding missing columns with NaN
for col in missing_in_csv:
    lista_spolek_csv[col] = None  # Add missing columns to CSV

for col in missing_in_www:
    lista_spolek_www[col] = None  # Add missing columns to Web data

# Step 5: Merge data side by side
comparison_df = pd.concat([lista_spolek_csv.add_suffix('_CSV'), lista_spolek_www.add_suffix('_WWW')], axis=1)

# Display results
print("\n📝 Side-by-side comparison of stock data:")
print(comparison_df.head(10))  # Show first 10 rows for preview

# Optional: Save to file for better readability
comparison_df.to_csv("comparison_output.csv", index=False)
print("\n📂 Comparison saved as 'comparison_output.csv'.")
# Out:
# Fetching fresh data from lista_spolek.py...
# ✅ Successfully retrieved fresh data from lista_spolek.py!
#
# 📥 Loading static data from CSV on GitHub...
#
# 📊 **Dataset Summary:**
# - 🖥️ `lista_spolek.py` output → Rows: 415, Columns: 1
# - 📄 CSV file from GitHub → Rows: 786, Columns: 2
#
# 🔍 Checking column differences...
# ⚠️ Columns in CSV but NOT in `lista_spolek.py` output: {'Ticker'}
#
# 📝 Side-by-side comparison of stock data:
#         Ticker_CSV Stock Parameter_CSV Stock Parameter_WWW Ticker_WWW
# 0  01C (01CYBATON)         01CYBERATON       06N (06MAGNA)       None
# 1    06N (06MAGNA)                 06N      08N (08OCTAVA)       None
# 2   08N (08OCTAVA)              OCTAVA         11B (11BIT)       None
# 3      11B (11BIT)      11-BIT-STUDIOS          1AT (ATAL)       None
# 4       1AT (ATAL)                ATAL       3RG (3RGAMES)       None
# 5    3RG (3RGAMES)                 3RG         4MS (4MASS)       None
# 6  4MB (4MOBILITY)           4MOBILITY          AAT (ALTA)       None
# 7      4MS (4MASS)                 4MS          ABE (ABPL)       None
# 8       7FT (7FIT)                 7FT      ABS (ASSECOBS)       None
# 9    7LV (7LEVELS)                 7LV     ACG (ACAUTOGAZ)       None
#
# 📂 Comparison saved as 'comparison_output.csv'.

# %%
import pandas as pd
import subprocess

# GitHub raw CSV URL
csv_url = 'https://raw.githubusercontent.com/lebinho/biznesradar/main/biznesradar_stocks_parameters.csv'

# Step 1: Try running lista_spolek.py to get fresh data
try:
    print("Fetching fresh data from lista_spolek.py...")
    
    # Run lista_spolek.py and capture output
    result = subprocess.run(['python', 'lista_spolek.py'], check=True, capture_output=True, text=True)
    
    # Convert output into a DataFrame
    company_names = result.stdout.strip().split("\n")  # Split output into lines
    lista_spolek_www = pd.DataFrame(company_names, columns=["Stock Parameter"])

    print("✅ Successfully retrieved fresh data from lista_spolek.py!")

except subprocess.CalledProcessError as e:
    print("❌ Error running lista_spolek.py:", e)
    print("Skipping comparison.")
    exit()  # Exit the script if lista_spolek.py fails

# Step 2: Load the CSV from GitHub
print("\n📥 Loading static data from CSV on GitHub...")
lista_spolek_csv = pd.read_csv(csv_url, sep=',')

# Step 3: Print dataset descriptions in table format
summary_df = pd.DataFrame({
    "Source": ["lista_spolek.py Output", "CSV from GitHub"],
    "Rows": [lista_spolek_www.shape[0], lista_spolek_csv.shape[0]],
    "Columns": [lista_spolek_www.shape[1], lista_spolek_csv.shape[1]]
})

print("\n📊 **Dataset Summary:**\n")
print(summary_df.to_string(index=False))  # Display table without index

# Step 4: Align columns (Check for missing columns)
print("\n🔍 Checking column differences...")

missing_in_csv = set(lista_spolek_www.columns) - set(lista_spolek_csv.columns)
missing_in_www = set(lista_spolek_csv.columns) - set(lista_spolek_www.columns)

if missing_in_csv:
    print(f"⚠️ Columns in `lista_spolek.py` output but NOT in CSV: {missing_in_csv}")

if missing_in_www:
    print(f"⚠️ Columns in CSV but NOT in `lista_spolek.py` output: {missing_in_www}")

# Ensure both have the same columns by adding missing columns with NaN
for col in missing_in_csv:
    lista_spolek_csv[col] = None  # Add missing columns to CSV

for col in missing_in_www:
    lista_spolek_www[col] = None  # Add missing columns to Web data

# Step 5: Merge data side by side with a clear separator
comparison_df = pd.concat([lista_spolek_csv.add_suffix('_CSV'), lista_spolek_www.add_suffix('_WWW')], axis=1)

# Add separator column
comparison_df.insert(len(lista_spolek_csv.columns), "|", "|")

# Select relevant columns with separator
ordered_columns = [
    "Ticker_CSV", "Stock Parameter_CSV", "|", "Ticker_WWW", "Stock Parameter_WWW"
]

# Ensure the ordered columns exist (some may be missing)
existing_columns = [col for col in ordered_columns if col in comparison_df.columns]
comparison_df = comparison_df[existing_columns]

# Display results
print("\n📝 Side-by-side comparison of stock data (first 10 rows):\n")
print(comparison_df.head(10).to_string(index=False))  # Print without index
# Out:
# Fetching fresh data from lista_spolek.py...
# ✅ Successfully retrieved fresh data from lista_spolek.py!
#
# 📥 Loading static data from CSV on GitHub...
#
# 📊 **Dataset Summary:**
#
#                 Source  Rows  Columns
# lista_spolek.py Output   768        1
#        CSV from GitHub   786        2
#
# 🔍 Checking column differences...
# ⚠️ Columns in CSV but NOT in `lista_spolek.py` output: {'Ticker'}
#
# 📝 Side-by-side comparison of stock data (first 10 rows):
#
#      Ticker_CSV Stock Parameter_CSV | Ticker_WWW                      Stock Parameter_WWW
# 01C (01CYBATON)         01CYBERATON |       None                        06N (06MAGNA),06N
#   06N (06MAGNA)                 06N |       None                    08N (08OCTAVA),OCTAVA
#  08N (08OCTAVA)              OCTAVA |       None               11B (11BIT),11-BIT-STUDIOS
#     11B (11BIT)      11-BIT-STUDIOS |       None                          1AT (ATAL),ATAL
#      1AT (ATAL)                ATAL |       None                        3RG (3RGAMES),3RG
#   3RG (3RGAMES)                 3RG |       None                          4MS (4MASS),4MS
# 4MB (4MOBILITY)           4MOBILITY |       None                           AAT (ALTA),AAT
#     4MS (4MASS)                 4MS |       None                           ABE (ABPL),ABE
#      7FT (7FIT)                 7FT |       None ABS (ASSECOBS),ASSECO-BUSINESS-SOLUTIONS
#   7LV (7LEVELS)                 7LV |       None                      ACG (ACAUTOGAZ),ACG

# %% [markdown]
# # Switched to lista_spolek_v2.py

# %%
import pandas as pd
import subprocess

# GitHub raw CSV URL
csv_url = 'https://raw.githubusercontent.com/lebinho/biznesradar/main/biznesradar_stocks_parameters.csv'

# Step 1: Try running lista_spolek_v2.py to get fresh data
try:
    print("Fetching fresh data from lista_spolek_v2.py...")

    # Run lista_spolek_v2.py and capture output
    result = subprocess.run(['python', 'lista_spolek_v2.py'], check=True, capture_output=True, text=True)

    # Convert output into a DataFrame, split by commas into two columns
    company_names = result.stdout.strip().split("\n")  # Split output into lines
    lista_spolek_www = pd.DataFrame([line.split(",") for line in company_names], columns=["Ticker", "Stock Parameter"])

    print("✅ Successfully retrieved fresh data from lista_spolek_v2.py!")

except subprocess.CalledProcessError as e:
    print("❌ Error running lista_spolek_v2.py:", e)
    print("Skipping comparison.")
    exit()  # Exit the script if lista_spolek_v2.py fails

# Step 2: Load the CSV from GitHub
print("\n📥 Loading static data from CSV on GitHub...")
lista_spolek_csv = pd.read_csv(csv_url, sep=',')

# Step 3: Print dataset descriptions in table format
summary_df = pd.DataFrame({
    "Source": ["lista_spolek_v2.py Output", "CSV from GitHub"],
    "Rows": [lista_spolek_www.shape[0], lista_spolek_csv.shape[0]],
    "Columns": [lista_spolek_www.shape[1], lista_spolek_csv.shape[1]]
})

print("\n📊 **Dataset Summary:**\n")
print(summary_df.to_string(index=False))  # Display table without index

# Step 4: Align columns (Check for missing columns)
print("\n🔍 Checking column differences...")

missing_in_csv = set(lista_spolek_www.columns) - set(lista_spolek_csv.columns)
missing_in_www = set(lista_spolek_csv.columns) - set(lista_spolek_www.columns)

if missing_in_csv:
    print(f"⚠️ Columns in `lista_spolek_v2.py` output but NOT in CSV: {missing_in_csv}")

if missing_in_www:
    print(f"⚠️ Columns in CSV but NOT in `lista_spolek_v2.py` output: {missing_in_www}")

# Ensure both have the same columns by adding missing columns with NaN
for col in missing_in_csv:
    lista_spolek_csv[col] = None  # Add missing columns to CSV

for col in missing_in_www:
    lista_spolek_www[col] = None  # Add missing columns to Web data

# Step 5: Merge data side by side with a clear separator
comparison_df = pd.concat([lista_spolek_csv.add_suffix('_CSV'), lista_spolek_www.add_suffix('_WWW')], axis=1)

# Add separator column
comparison_df.insert(len(lista_spolek_csv.columns), "|", "|")

# Select relevant columns with separator
ordered_columns = [
    "Ticker_CSV", "Stock Parameter_CSV", "|", "Ticker_WWW", "Stock Parameter_WWW"
]

# Ensure the ordered columns exist (some may be missing)
existing_columns = [col for col in ordered_columns if col in comparison_df.columns]
comparison_df = comparison_df[existing_columns]

# Display results
print("\n📝 Side-by-side comparison of stock data (first 10 rows):\n")
print(comparison_df.head(1000).to_string(index=False))  # Print without index
# Out:
# Fetching fresh data from lista_spolek_v2.py...
# ✅ Successfully retrieved fresh data from lista_spolek_v2.py!
#
# 📥 Loading static data from CSV on GitHub...
#
# 📊 **Dataset Summary:**
#
#                    Source  Rows  Columns
# lista_spolek_v2.py Output   768        2
#           CSV from GitHub   786        2
#
# 🔍 Checking column differences...
#
# 📝 Side-by-side comparison of stock data (first 10 rows):
#
#          Ticker_CSV               Stock Parameter_CSV |          Ticker_WWW               Stock Parameter_WWW
#     01C (01CYBATON)                       01CYBERATON |       06N (06MAGNA)                               06N
#       06N (06MAGNA)                               06N |      08N (08OCTAVA)                            OCTAVA
#      08N (08OCTAVA)                            OCTAVA |         11B (11BIT)                    11-BIT-STUDIOS
#         11B (11BIT)                    11-BIT-STUDIOS |          1AT (ATAL)                              ATAL
#          1AT (ATAL)                              ATAL |       3RG (3RGAMES)                               3RG
#       3RG (3RGAMES)                               3RG |         4MS (4MASS)                               4MS
#     4MB (4MOBILITY)                         4MOBILITY |          AAT (ALTA)                               AAT
#         4MS (4MASS)                               4MS |          ABE (ABPL)                               ABE
#          7FT (7FIT)                               7FT |      ABS (ASSECOBS)         ASSECO-BUSINESS-SOLUTIONS
#       7LV (7LEVELS)                               7LV |     ACG (ACAUTOGAZ)                               ACG
#     AAS (AALLIANCE)                               AAS |     ACP (ASSECOPOL)                     ASSECO-POLAND
#          AAT (ALTA)                               AAT |        ACT (ACTION)                            ACTION
#          ABE (ABPL)                               ABE |        ADV (ADIUVO)                 ADIUVO-INVESTMENT
#          ABK (ABAK)                              ABAK |         AGO (AGORA)                             AGORA
#      ABS (ASSECOBS)         ASSECO-BUSINESS-SOLUTIONS |       AGT (AGROTON)                           AGROTON
#       ACA (ACARTUS)                           ACARTUS |     AIN (ABSINVEST)                    ABS-INVESTMENT
#     ACG (ACAUTOGAZ)                               ACG |       ALE (ALLEGRO)                               ALE
#     ACP (ASSECOPOL)                     ASSECO-POLAND |       ALG (AIGAMES)                               ALG
#        ACT (ACTION)                            ACTION |         ALI (ALTUS)                             ALTUS
#        ADS (ADIDAS)                               ADS |      ALL (AILLERON)                               ALL
#        ADV (ADIUVO)                 ADIUVO-INVESTMENT |         ALR (ALIOR)                        ALIOR-BANK
#        ADX (ADATEX)                               ADX |         AMB (AMBRA)                             AMBRA
#     AER (AERFINANC)                        HYDROPRESS |         AMC (AMICA)                             AMICA
#     AFC (AKCEPTFIN)                    AKCEPT-FINANCE |       ANR (ANSWEAR)                               ANR
#         AFH (AFHOL)                    AFORTI-HOLDING |     APE (APSENERGY)                       APS-ENERGIA
#      AGL (AGROLIGA)                    AGROLIGA-GROUP |         APL (AMPLI)                             AMPLI
#         AGO (AGORA)                             AGORA |      APN (APLISENS)                          APLISENS
#       AGP (AGROMEP)                           AGROMEP |     APR (AUTOPARTN)                               APR
#       AGT (AGROTON)                           AGROTON |        APT (APATOR)                            APATOR
#     AIN (ABSINVEST)                    ABS-INVESTMENT |      ARH (ARCHICOM)                               ARH
#         AIT (AITON)                    AITON-CALDWELL |       ART (ARTIFEX)                           ARTIFEX
#       ALE (ALLEGRO)                               ALE |         ASB (ASBIS)                            ASBISC
#       ALG (AIGAMES)                               ALG |     ASE (ASSECOSEE)       ASSECO-SOUTH-EASTERN-EUROPE
#         ALI (ALTUS)                             ALTUS |      ASM (ASMGROUP)                         ASM-GROUP
#      ALL (AILLERON)                               ALL |       AST (ASTARTA)                           ASTARTA
#         ALR (ALIOR)                        ALIOR-BANK |        ATC (ARCTIC)                      ARCTIC-PAPER
#       ALV (ALLIANZ)                               ALV |        ATD (ATENDE)                            ATENDE
#         AMB (AMBRA)                             AMBRA |      ATG (ATMGRUPA)                         ATM-GRUPA
#         AMC (AMICA)                             AMICA |     ATP (ATLANTAPL)                    ATLANTA-POLAND
#      AML (ALUMETAL)                          ALUMETAL |         ATR (ATREM)                             ATREM
#       AMV (ASMODEV)                               AMV |      ATS (ATLANTIS)                               ATS
#       ANR (ANSWEAR)                               ANR |    ATT (GRUPAAZOTY)                               ATT
#       AOL (ANALIZY)                    ANALIZY-ONLINE |        AWM (AIRWAY)                      AIRWAY-MEDIX
#        APA (APANET)                            APANET |       B24 (BRAND24)                               B24
#        APC (APOLLO)                               APC |        BBD (BBIDEV)                   BBI-DEVELOPMENT
#     APE (APSENERGY)                       APS-ENERGIA |       BBT (BOOMBIT)                               BBT
#         APL (AMPLI)                             AMPLI |       BCM (BETACOM)                           BETACOM
#      APN (APLISENS)                          APLISENS |     BCS (BIGCHEESE)                               BCS
#     APR (AUTOPARTN)                               APR |     BCX (BIOCELTIX)                               BCX
#                 APS                               APS |       BDX (BUDIMEX)                           BUDIMEX
#        APT (APATOR)                            APATOR |        BDZ (BEDZIN)          ELEKTROCIEPLOWNIA-BEDZIN
#       AQA (AQUAPOZ)                              AQUA |       BFT (BENEFIT)                   BENEFIT-SYSTEMS
#      AQT (AQUATECH)                               AQT |      BHW (HANDLOWY)                     BANK-HANDLOWY
#        AQU (AQUABB)                AQUA-BIELSKO-BIALA |        BIO (BIOTON)                            BIOTON
#       ARE (ARENAPL)                               ARE |     BIP (BIOPLANET)                        BIO-PLANET
#      ARG (ARTGAMES)                               ARG |       BLO (BLOOBER)                      BLOOBER-TEAM
#      ARH (ARCHICOM)                               ARH |        BMC (BUMECH)                            BUMECH
#                 ARI         AGENCJA-ROZWOJU-INNOWACJI |     BMX (BIOMAXIMA)                         BIOMAXIMA
#       ART (ARTIFEX)                           ARTIFEX |        BNP (BNPPPL)                               BNP
#          ASA (APIS)                              APIS |                 BOS           BANK-OCHRONY-SRODOWISKA
#         ASB (ASBIS)                            ASBISC |         BOW (BOWIM)                             BOWIM
#     ASE (ASSECOSEE)       ASSECO-SOUTH-EASTERN-EUROPE |       BRA (BRASTER)                           BRASTER
#      ASM (ASMGROUP)                         ASM-GROUP |      BRS (BORYSZEW)                          BORYSZEW
#         ASR (ASTRO)                             ASTRO |          BST (BEST)                              BEST
#       AST (ASTARTA)                           ASTARTA |       CAP (CAPITEA)                               CAP
#      ATA (ATCCARGO)                         ATC-CARGO |     CAR (INTERCARS)                        INTER-CARS
#        ATC (ARCTIC)                      ARCTIC-PAPER |      CAV (CAVATINA)                               CAV
#        ATD (ATENDE)                            ATENDE |     CBF (CYBERFLKS)                               CBF
#      ATG (ATMGRUPA)                         ATM-GRUPA |                 CCC                               CCC
#     ATJ (ATOMJELLY)                               ATJ |      CCE (CCENERGY)               CLEAN-CARBON-ENERGY
#        ATO (ATONHT)                           ATON-HT |          CDL (CDRL)                               CDL
#     ATP (ATLANTAPL)                    ATLANTA-POLAND |     CDR (CDPROJEKT)                        CD-PROJEKT
#         ATR (ATREM)                             ATREM |                 CEZ                               CEZ
#      ATS (ATLANTIS)                               ATS |                 CFI                       CFI-HOLDING
#    ATT (GRUPAAZOTY)                               ATT |       CIG (CIGAMES)                          CI-GAMES
#       AUX (AUXILIA)                               AUX |      CLC (COLUMBUS)                  COLUMBUS-CAPITAL
#     AVE (ADVERTIGO)                         ADVERTIGO |         CLD (CLOUD)                CLOUD-TECHNOLOGIES
#        AWM (AIRWAY)                      AIRWAY-MEDIX |     CLE (COALENERG)                       COAL-ENERGY
#         AZC (AZTEC)               AZTEC-INTERNATIONAL |     CLN (CLNPHARMA)                         CLNPHARMA
#       B24 (BRAND24)                               B24 |          CMP (COMP)                              COMP
#     BAH (BAHOLDING)                         BAHOLDING |       CMR (COMARCH)                           COMARCH
#         BAY (BAYER)                               BAY |        COG (COGNOR)                            COGNOR
#        BBD (BBIDEV)                   BBI-DEVELOPMENT |       CPA (CAPITAL)                  CAPITAL-PARTNERS
#       BBT (BOOMBIT)                               BBT |        CPD (CELTIC)                               CPD
#       BCM (BETACOM)                           BETACOM |      CPL (COMPERIA)                       COMPERIA-PL
#     BCS (BIGCHEESE)                               BCS |     CPR (COMPREMUM)                               CPR
#     BCX (BIOCELTIX)                               BCX |     CPS (CYFRPLSAT)                    CYFROWY-POLSAT
#       BDX (BUDIMEX)                           BUDIMEX |     CRC (CARPATHIA)                               CRC
#        BDZ (BEDZIN)          ELEKTROCIEPLOWNIA-BEDZIN |      CRI (CREOTECH)                               CRI
#         BEE (BEEIN)                               BEE |     CRJ (CREEPYJAR)                               CRJ
#       BEP (BIOMASS)            BIOMASS-ENERGY-PROJECT |        CRM (CORMAY)                            CORMAY
#        BER (BIOERG)                            BIOERG |        CSR (CASPAR)           CASPAR-ASSET-MANAGEMENT
#     BFC (BIOFACTOR)                        BIOFACTORY |     CTF (CENTURION)                 CENTURION-FINANCE
#       BFT (BENEFIT)                   BENEFIT-SYSTEMS |      CTS (CITYSERV)                               CTS
#      BGD (BIOGENED)                          BIOGENED |      CTX (CAPTORTX)                               CTX
#      BHW (HANDLOWY)                     BANK-HANDLOWY | CTXA (CAPTORTX-PDA)                              CTXA
#        BHX (BINARY)                      BINARY-HELIX |     CZT (CZTOREBKA)                  CZERWONA-TOREBKA
#        BIO (BIOTON)                            BIOTON |        DAD (DADELO)                               DAD
#     BIP (BIOPLANET)                        BIO-PLANET |      DAT (DATAWALK)                               DAT
#      BKD (BKDGAMES)                               BKD |        DBC (DEBICA)                            DEBICA
#       BLO (BLOOBER)                      BLOOBER-TEAM |      DBE (DBENERGY)                               DBE
#      BLT (BALTICON)                          BALTICON |        DCR (DECORA)                            DECORA
#        BMC (BUMECH)                            BUMECH |        DEK (DEKPOL)                            DEKPOL
#                 BMW                               BMW |         DEL (DELKO)                             DELKO
#     BMX (BIOMAXIMA)                         BIOMAXIMA |                 DGA                               DGA
#        BNP (BNPPPL)                               BNP |      DGE (DRAGOENT)                               DGE
#                 BOS           BANK-OCHRONY-SRODOWISKA |     DIG (DIGITANET)                               DIG
#         BOW (BOWIM)                             BOWIM |       DMG (DMGROUP)                               DMG
#                 BPC               BLACK-PEARL-CAPITAL |        DNP (DINOPL)                               DNP
#     BPN (BLACKPOIN)                       BLACK-POINT |        DOM (DOMDEV)                   DOM-DEVELOPMENT
#       BRA (BRASTER)                           BRASTER |      DPL (DROZAPOL)                   DROZAPOL-PROFIL
#     BRH (BERGHOLDI)                               BRH |      DTR (DIGITREE)                               DTR
#      BRO (CZARNKOW)                  BROWAR-GONTYNIEC |       DVL (DEVELIA)                               DVL
#     BRP (BLACKROSE)                               BRP |        EAH (ESOTIQ)                  ESOTIQ-HENDERSON
#      BRS (BORYSZEW)                          BORYSZEW |        EAT (AMREST)                               EAT
#          BSA (BRAS)                              BRAS |          ECH (ECHO)                   ECHO-INVESTMENT
#                 BSH                               BSH |      EDI (EDINVEST)                         ED-INVEST
#          BST (BEST)                              BEST |     EEX (EKOEXPORT)                        EKO-EXPORT
#     BTC (BTCSTUDIO)                               BTC |         EFK (EFEKT)                             EFEKT
#       BTG (BLUETAX)                    BLUE-TAX-GROUP |      EHG (EUROHOLD)                 EUROHOLD-BULGARIA
#       BTK (BIZTECH)                               BTK |         EKP (ELKOP)                             ELKOP
#       BTX (BETOMAX)                               BTX |     ELT (ELEKTROTI)                        ELEKTROTIM
#                 BVT                               BVT |     EMC (EMCINSMED)                               EMC
#       CAI (CARLSON)                               CAI |          ENA (ENEA)                               ENA
#     CAR (INTERCARS)                        INTER-CARS |       ENE (ENELMED)                          ENEL-MED
#      CAV (CAVATINA)                               CAV |        ENG (ENERGA)                            ENERGA
#      CBD (CANNABIS)                               CBD |     ENI (ENERGOINS)                      ENERGOINSTAL
#     CBF (CYBERFLKS)                               CBF |          ENP (ENAP)                   ENERGOAPARATURA
#                 CCC                               CCC |         ENT (ENTER)                               ENT
#      CCE (CCENERGY)               CLEAN-CARBON-ENERGY |       EQU (EQUNICO)                               EQU
#     CCR (CONSTANCE)                               CCR |         ERB (ERBUD)                             ERBUD
#                 CCS         CYFROWE-CENTRUM-SERWISOWE |                 ERG                               ERG
#                 CDA                               CDA |         EST (ESTAR)                               EST
#          CDL (CDRL)                               CDL |       ETL (EUROTEL)                           EUROTEL
#     CDR (CDPROJEKT)                        CD-PROJEKT |          EUC (EUCO)   EUROPEJSKIE-CENTRUM-ODSZKODOWAN
#                 CEZ                               CEZ |      EUR (EUROCASH)                          EUROCASH
#                 CFG                               CFG |       FAB (FABRITY)                               FAB
#                 CFI                       CFI-HOLDING |        FEE (FEERUM)                            FEERUM
#          CFS (CFSA)                               CFS |       FFI (FASTFIN)                      FAST-FINANCE
#        CHP (CHERRY)                               CHP |                 FMG                               FMG
#         CIE (CIECH)                             CIECH |                 FON                               FON
#       CIG (CIGAMES)                          CI-GAMES |         FRO (FERRO)                             FERRO
#       CLA (CONSOLE)                               CLA |        FSG (FASING)                            FASING
#      CLC (COLUMBUS)                  COLUMBUS-CAPITAL |         FTE (FORTE)                             FORTE
#         CLD (CLOUD)                CLOUD-TECHNOLOGIES |      GEA (GRENEVIA)                          GRENEVIA
#     CLE (COALENERG)                       COAL-ENERGY |     GIF (GAMFACTOR)                               GIF
#     CLN (CLNPHARMA)                         CLNPHARMA |       GIG (GIGROUP)                               GIG
#        CMC (COMECO)                            COMECO |      GKI (IMMOBILE)                               GKI
#                 CMI                               CMI |      GMT (GENOMTEC)                               GMT
#          CMP (COMP)                              COMP |       GOB (GOBARTO)                           GOBARTO
#       CMR (COMARCH)                           COMARCH |       GOP (GAMEOPS)                               GOP
#        COG (COGNOR)                            COGNOR |     GPP (GRUPRACUJ)                               GPP
#         COS (COSMA)                               COS |                 GPW                               GPW
#       CPA (CAPITAL)                  CAPITAL-PARTNERS |        GRN (GRODNO)                            GRODNO
#        CPD (CELTIC)                               CPD |        GRX (GREENX)                               GRX
#       CPG (CPGROUP)                      CAPITAL-PARK |                 GTC                               GTC
#      CPL (COMPERIA)                       COMPERIA-PL |         GTN (GETIN)                     GETIN-HOLDING
#     CPR (COMPREMUM)                               CPR |      HDR (HYDROTOR)                          HYDROTOR
#     CPS (CYFRPLSAT)                    CYFROWY-POLSAT |         HEL (HELIO)                             HELIO
#     CRB (CARBONSTU)                               CRB |     HLD (HOLLYWOOD)                         HOLLYWOOD
#     CRC (CARPATHIA)                               CRC |      HMI (HMINWEST)                         HM-INWEST
#      CRI (CREOTECH)                               CRI |        HRP (HARPER)                  HARPER-HYGIENICS
#     CRJ (CREEPYJAR)                               CRJ |      HRS (HERKULES)                          HERKULES
#        CRM (CORMAY)                            CORMAY |        HUG (HUUUGE)                               HUG
#     CRP (CEREALPLT)                     CEREAL-PLANET |          IBS (IBSM)                              IBSM
#      CRS (COPERNIC)             COPERNICUS-SECURITIES |      ICE (MEDINICE)                               ICE
#        CSR (CASPAR)           CASPAR-ASSET-MANAGEMENT |        IDG (INDYGO)               INDYGOTECH-MINERALS
#     CTF (CENTURION)                 CENTURION-FINANCE |         IDM (IDMSA)                               IDM
#      CTS (CITYSERV)                               CTS |     IFC (IFCAPITAL)                               IFC
#      CTX (CAPTORTX)                               CTX |        IFI (IFIRMA)                               IFI
#     CZT (CZTOREBKA)                  CZERWONA-TOREBKA |          IFR (IFSA)                               IFR
#        DAD (DADELO)                               DAD |         IIA (IIAAV)                               IIA
#      DAT (DATAWALK)                               DAT |     IMC (IMCOMPANY)           INDUSTRIAL-MILK-COMPANY
#        DBC (DEBICA)                            DEBICA |       IMP (IMPERIO)                               IMP
#      DBE (DBENERGY)                               DBE |                 IMS                               IMS
#        DCR (DECORA)                            DECORA |                 INC                               INC
#     DDI (DDISTANCE)                               DDI |        ING (INGBSK)                   ING-BANK-SLASKI
#      DEG (DETGAMES)                               DEG |     INK (INSTALKRK)                     INSTAL-KRAKOW
#        DEK (DEKPOL)                            DEKPOL |        INL (INTROL)                            INTROL
#         DEL (DELKO)                             DELKO |         INP (INPRO)                             INPRO
#       DEV (DEVORAN)                               DEV |       IPE (IPOPEMA)                           IPOPEMA
#                 DGA                               DGA |     IPO (INTERSPPL)                         INTERSPPL
#      DGE (DRAGOENT)                               DGE |     IRL (INTERAOLT)                 INTER-RAO-LIETUVA
#         DGN (DGNET)                               DGN |      ITB (INTERBUD)                   INTERBUD-LUBLIN
#     DIG (DIGITANET)                        4FUN-MEDIA |       IZB (IZOBLOK)                           IZOBLOK
#        DKR (DEKTRA)                            DEKTRA |      IZO (IZOLACJA)                  IZOLACJA-JAROCIN
#        DNP (DINOPL)                               DNP |       IZS (IZOSTAL)                           IZOSTAL
#         DNS (DANKS)                             DANKS |                 JRH                               JRH
#          DOK (DOOK)                               DOK |                 JSW    JSW-JASTRZEBSKA-SPOLKA-WEGLOWA
#        DOM (DOMDEV)                   DOM-DEVELOPMENT |     JWW (JWWINVEST)                        JWW-INVEST
#       DOW (DSTREAM)                               DOW |      KCH (KRAKCHEM)                        KRAKCHEMIA
#      DPL (DROZAPOL)                   DROZAPOL-PROFIL |                 KCI                               KCI
#     DRF (DRFINANCE)                               DRF |     KDM (KDMSHIPNG)       KDM-SHIPPING-PUBLIC-LIMITED
#       DRG (DRAGEUS)                               DRG |        KER (KERNEL)                            KERNEL
#      DTR (DIGITREE)                               DTR |          KGH (KGHM)                              KGHM
#         DTX (DITIX)                               DTX |                 KGL                               KGL
#       DUA (DUALITY)                               DUA |      KGN (KOGENERA)                       KOGENERACJA
#       DVL (DEVELIA)                               DVL |        KMP (KOMPAP)                            KOMPAP
#        EAH (ESOTIQ)                  ESOTIQ-HENDERSON |     KOM (KOMPUTRON)                       KOMPUTRONIK
#        EAT (AMREST)                               EAT |          KPD (KPPD)                               KPD
#        EBX (EKOBOX)                            EKOBOX |       KPL (KINOPOL)                    KINO-POLSKA-TV
#      ECC (ECCGAMES)                               ECC |      KRI (KREDYTIN)                     KREDYT-INKASO
#          ECH (ECHO)                   ECHO-INVESTMENT |          KRK (KRKA)                              KRKA
#     ECK (EUROSNACK)                         EUROSNACK |          KRU (KRUK)                              KRUK
#      ECL (EASYCALL)                       EASYCALL-PL |       KSG (KSGAGRO)                          KSG-AGRO
#      ECT (ECO5TECH)                               ECT |          KTY (KETY)                              KETY
#      EDI (EDINVEST)                         ED-INVEST |     KVT (KRVITAMIN)                               KVT
#      EDL (EDITELPL)                     EDISON-SPOLKA |     LAB (LABOPRINT)                        LABO-PRINT
#         EEE (EKIPA)                               EEE |         LBT (LIBET)                             LIBET
#     EEX (EKOEXPORT)                        EKO-EXPORT |        LBW (LUBAWA)                            LUBAWA
#     EFE (EFENERGII)        EUROPEJSKI-FUNDUSZ-ENERGII |          LEN (LENA)                     LENA-LIGHTING
#         EFK (EFEKT)                             EFEKT |          LES (LESS)                               LES
#        EGH (EKOPOL)                            EKOPOL |         LKD (LOKUM)                               LKD
#      EHG (EUROHOLD)                 EUROHOLD-BULGARIA |                 LPP                               LPP
#        EKE (EKOOZE)                               EKE |          LRK (LARK)                               LRK
#         EKP (ELKOP)                             ELKOP |          LRQ (LARQ)                               LRQ
#        EKS (EKIOSK)                           E-KIOSK |       LSI (LSISOFT)                      LSI-SOFTWARE
#         ELM (EMONT)                       ELEKTROMONT |        LTX (LENTEX)                            LENTEX
#                 ELQ                               ELQ |      LWB (BOGDANKA)                          BOGDANKA
#     ELT (ELEKTROTI)                        ELEKTROTIM |        MAB (MABION)                            MABION
#         ELZ (ELZAB)                             ELZAB |     MAK (MAKARONPL)                  MAKARONY-POLSKIE
#       EMA (EMTASIA)                               EMA |       MAN (MANYDEV)                               MAN
#     EMC (EMCINSMED)                               EMC |         MBK (MBANK)                             MBANK
#     EMP (EMPLOCITY)                               EMP |        MBR (MOBRUK)                               MBR
#       EMU (EMUZYKA)                          E-MUZYKA |          MBW (MBWS)                               MBW
#          ENA (ENEA)                               ENA |                 MCI                               MCI
#        END (ENEIDA)                               END |        MCR (MERCOR)                            MERCOR
#       ENE (ENELMED)                          ENEL-MED |      MDG (MEDICALG)                               MDG
#        ENG (ENERGA)                            ENERGA |    MDI (MDIENERGIA)                               MDI
#     ENI (ENERGOINS)                      ENERGOINSTAL |       MEG (MEGARON)                           MEGARON
#          ENP (ENAP)                   ENERGOAPARATURA |     MEX (MEXPOLSKA)                        MEX-POLSKA
#         ENT (ENTER)                               ENT |                 MFO                               MFO
#         EON (EONET)                       EO-NETWORKS |       MGT (MANGATA)                               MGT
#       EPR (EKOPARK)                               EPR |    MIL (MILLENNIUM)                   BANK-MILLENNIUM
#      ERA (ERATONRG)                         TECHINVGR |     MIR (MIRACULUM)                         MIRACULUM
#         ERB (ERBUD)                             ERBUD |      MLG (MLPGROUP)                         MLP-GROUP
#                 ERG                               ERG |     MLK (MILKILAND)                               MLK
#     ESG (ESHOPPING)                               ESG |      MLS (MLSYSTEM)                               MLS
#       ESK (ESKIMOS)                           ESKIMOS |       MNC (MENNICA)                    MENNICA-POLSKA
#         EST (ESTAR)                               EST |      MOC (MOLECURE)                               MOC
#       ETL (EUROTEL)                           EUROTEL |                 MOJ                               MOJ
#       ETX (EUROTAX)                       EURO-TAX-PL |                 MOL                   MOL-MAGYAR-OLAJ
#          EUC (EUCO)   EUROPEJSKIE-CENTRUM-ODSZKODOWAN |       MON (MONNARI)                     MONNARI-TRADE
#      EUR (EUROCASH)                          EUROCASH |    MOV (MOVIEGAMES)                               MOV
#     EXA (EXAMOBILE)                         EXAMOBILE |        MRB (MIRBUD)                            MIRBUD
#     EXC (EXCELLENC)                        EXCELLENCE |      MRC (MERCATOR)                          MERCATOR
#        EXM (EXIMIT)                               EXM |     MSP (MOSTALPLC)                   MOSTOSTAL-PLOCK
#        F51 (FARM51)                 THE-FARM-51-GROUP |     MSW (MOSTALWAR)                MOSTOSTAL-WARSZAWA
#        FEE (FEERUM)                            FEERUM |     MSZ (MOSTALZAB)                  MOSTOSTAL-ZABRZE
#       FEM (FEMTECH)                               FEM |       MUR (MURAPOL)                               MUR
#        FER (FERRUM)                            FERRUM |      MVP (MARVIPOL)                               MVP
#       FFI (FASTFIN)                      FAST-FINANCE |       MWT (MWTRADE)                          MW-TRADE
#         FHD (FHDOM)            FUNDUSZ-HIPOTECZNY-DOM |        MXC (MAXCOM)                               MXC
#        FIG (FIGENE)                               FIG |          MZA (MUZA)                              MUZA
#     FKD (FABRYKAKD)   FABRYKA-KONSTRUKCJI-DREWNIANYCH |     NCL (NOCTILUCA)                               NCL
#        FLG (FALCON)                               FLG |         NEU (NEUCA)                             NEUCA
#                 FMG                               FMG |     NNG (NANOGROUP)                               NNG
#                 FON                               FON |     NTC (NTCAPITAL)                               NTC
#     FOR (FOREVEREN)             FOREVER-ENTERTAINMENT |     NTT (NTTSYSTEM)                               NTT
#      FPO (FORPOSTA)                          FORPOSTA |     NTU (NOVATURAS)                               NTU
#         FRO (FERRO)                             FERRO |        NVA (PANOVA)                            PANOVA
#     FRW (FROZENWAY)                               FRW |     NVG (NOVAVISGR)                               NVG
#        FSG (FASING)                            FASING |        NVT (NOVITA)                            NOVITA
#         FTE (FORTE)                             FORTE |         NWG (NEWAG)                             NEWAG
#       FTH (FINTECH)                               FTH |        NXG (NEXITY)                               NXG
#     FTL (FOOTHILLS)                               FTL |      OBL (ORZBIALY)                       ORZEL-BIALY
#      FVE (FOTOVOLT)                               FVE |      ODL (ODLEWNIE)                  ODLEWNIE-POLSKIE
#         GAL (GALVO)                             GALVO |          OND (ONDE)                               OND
#         GAR (GARIN)                               GAR |       ONO (ONESANO)                               ONO
#       GBK (GETBACK)                               GBK |     OPG (ORCOGROUP)                               OPG
#      GDC (GAMEDUST)                               GDC |      OPL (ORANGEPL)                            ORANGE
#      GEA (GRENEVIA)                          GRENEVIA |        OPM (OPTEAM)                            OPTEAM
#       GEN (GENOMED)                           GENOMED |     OPN (OPONEO.PL)                         OPONEO-PL
#     GHY (GHYDROGEN)                    TELIANI-VALLEY |      OTM (OTMUCHOW)                          OTMUCHOW
#     GIF (GAMFACTOR)                               GIF |         OTS (OTLOG)                      OT-LOGISTICS
#       GIG (GIGROUP)                               GIG |       OVO (OVOSTAR)                           OVOSTAR
#      GKI (IMMOBILE)                               GKI |        PAS (PASSUS)                               PAS
#        GKS (GKSKAT)               GKS-GIEKSA-KATOWICE |      PAT (PATENTUS)                          PATENTUS
#      GLC (GLCOSMED)                     GLOBAL-COSMED |    PBF (PBSFINANSE)                       PBS-FINANSE
#      GMB (GAMESBOX)                               GMB |                 PBG                               PBG
#       GME (GRMEDIA)                               GME |       PBX (PEKABEX)                           PEKABEX
#      GMT (GENOMTEC)                               GMT |        PCE (POLICE)                            POLICE
#        GMV (GAMIVO)                               GMV |      PCF (PCFGROUP)                               PCF
#       GMZ (GRUPAMZ)                               GMZ |         PCO (PEPCO)                               PCO
#         GNG (GENRG)                          G-ENERGY |     PCR (PCCROKITA)                            ROKITA
#       GOB (GOBARTO)                           GOBARTO |       PCX (PCCEXOL)                          PCC-EXOL
#         GOL (GOLAB)                             GOLAB |        PEN (PHOTON)                            PHOTON
#       GOP (GAMEOPS)                               GOP |         PEO (PEKAO)                             PEKAO
#        GOV (GOVENA)                               GOV |                 PEP                        POLENERGIA
#      GPH (GRAPHENE)                               GPH |                 PGE                               PGE
#     GPP (GRUPRACUJ)                               GPP |          PGM (PMPG)                               PGM
#                 GPW                               GPW |      PGV (PGFGROUP)                               PGV
#      GRC (GRUPAREC)                      GRUPA-RECYKL |                 PHN      POLSKI-HOLDING-NIERUCHOMOSCI
#     GRE (GREENENER)                               GRE |      PHR (PHARMENA)                          PHARMENA
#       GRM (GREMPCO)                           GREMPCO |     PJP (PJPMAKRUM)                         PROJPRZEM
#        GRN (GRODNO)                            GRODNO |      PKN (PKNORLEN)                             ORLEN
#        GRX (GREENX)                               GRX |         PKO (PKOBP)                               PKO
#                 GTC                               GTC |      PKP (PKPCARGO)                          PKPCARGO
#         GTF (GOTFI)                            GO-TFI |       PLW (PLAYWAY)                           PLAYWAY
#         GTN (GETIN)                     GETIN-HOLDING |     PLZ (PLAZACNTR)                         PLAZACNTR
#       GTP (GEOTERM)                          GEO-TERM |     PMA (PRIMAMODA)                        PRIMA-MODA
#      GTS (GEOTRANS)                               GTS |       PMP (PAMAPOL)                           PAMAPOL
#      GTY (GTRINITY)                     GRUPA-TRINITY |        PPS (PEPEES)                            PEPEES
#       GX1 (GENXONE)                               GX1 |     PRI (PRAGMAINK)                               PRI
#      HDR (HYDROTOR)                          HYDROTOR |       PRM (PROCHEM)                           PROCHEM
#         HEL (HELIO)                             HELIO |     PRT (PROTEKTOR)                         PROTEKTOR
#     HLD (HOLLYWOOD)                         HOLLYWOOD |       PTG (POLTREG)                               PTG
#      HMI (HMINWEST)                         HM-INWEST |          PTW (PTWP)                              PTWP
#          HMP (HEMP)                               HMP |          PUR (PURE)                               PUR
#       HOR (HORTICO)                           HORTICO |        PWX (POLWAX)                            POLWAX
#     HPM (HIPROMINE)                               HPM |     PXM (POLIMEXMS)                           POLIMEX
#     HPS (HYDRAPRES)                         HYDRAPRES |                 PZU                               PZU
#      HRC (GRUPAHRC)                         GRUPA-HRC |       QNT (QUANTUM)                  QUANTUM-SOFTWARE
#     HRL (HORNIGOLD)                               HRL |       QRS (QUERCUS)                           QUERCUS
#        HRP (HARPER)                  HARPER-HYGIENICS |          RAE (RAEN)                               RAE
#      HRS (HERKULES)                          HERKULES |       RAF (RAFAMET)                           RAFAMET
#      HRT (HURTIMEX)                          HURTIMEX |       RBW (RAINBOW)                     RAINBOW-TOURS
#       HUB (HUBTECH)                               HUB |         RDN (REDAN)                             REDAN
#        HUG (HUUUGE)                               HUG |        REG (REGNON)                            REGNON
#     IBC (IBCPOLSKA)                        IBC-POLSKA |        RFK (RAFAKO)                            RAFAKO
#          IBS (IBSM)                              IBSM |      RHD (REINHOLD)                          REINHOLD
#        ICA (INCANA)                            INCANA |        RLP (RELPOL)                            RELPOL
#          ICD (ICPD) INTERCAPITAL-PROPERTY-DEVELOPMENT |         RMK (REMAK)                             REMAK
#      ICE (MEDINICE)                               ICE |         RNC (REINO)                               RNC
#       ICG (ICECODE)                               ICG |        RND (RENDER)                               RND
#        IDG (INDYGO)               INDYGOTECH-MINERALS |     RNK (RANKPROGR)                     RANK-PROGRESS
#                 IDH                               IDH |      RPC (ROPCZYCE)                          ROPCZYCE
#         IDM (IDMSA)                               IDM |          RVU (RYVU)                               RVU
#         IFA (INFRA)                             INFRA |      RWL (RAWLPLUG)                          RAWLPLUG
#     IFC (IFCAPITAL)                               IFC |     SAN (SANTANDER)                         SANTANDER
#        IFI (IFIRMA)                               IFI |         SCP (SCPFL)                               SCP
#          IFR (IFSA)                               IFR |          SEK (SEKO)                              SEKO
#      IGN (INNOGENE)                         INNO-GENE |      SEL (SELENAFM)                         SELENA-FM
#        IGT (IGORIA)                      IGORIA-TRADE |       SEN (SERINUS)                               SEN
#         IIA (IIAAV)                               IIA |       SFG (SILVANO)                AS-SILVANO-FASHION
#     IMC (IMCOMPANY)           INDUSTRIAL-MILK-COMPANY |        SFS (SFINKS)                            SFINKS
#      IMG (IMMGAMES)                               IMG |       SGN (SYGNITY)                           SYGNITY
#       IMP (IMPERIO)                               IMP |      SGR (SADOVAYA)                          SADOVAYA
#          IMR (INTM)                               IMR |       SHD (SOHODEV)                  SOHO-DEVELOPMENT
#                 IMS                               IMS |     SHG (STARHEDGE)                         STARHEDGE
#                 INC                               INC |        SHO (SHOPER)                               SHO
#        ING (INGBSK)                   ING-BANK-SLASKI |     SIM (SIMFABRIC)                               SIM
#     INK (INSTALKRK)                     INSTAL-KRAKOW |       SKA (SNIEZKA)                           SNIEZKA
#        INL (INTROL)                            INTROL |      SKH (SKARBIEC)                  SKARBIEC-HOLDING
#     INM (INVENTION)                      INVENTIONMED |       SKL (SKYLINE)                SKYLINE-INVESTMENT
#         INP (INPRO)                             INPRO |       SLV (SELVITA)                               SLV
#         INS (INDOS)                               INS |         SNK (SANOK)                               SNK
#     INT (INTERNITY)                   NTERNITY-SPOLKA |      SNT (SYNEKTIK)                          SYNEKTIK
#       IPE (IPOPEMA)                           IPOPEMA |        SNW (SANWIL)                    SANWIL-HOLDING
#     IPO (INTERSPPL)                         INTERSPPL |         SNX (SUNEX)                             SUNEX
#      IPW (IMAGEPWR)                               IPW |         SON (SONEL)                             SONEL
#     IRL (INTERAOLT)                 INTER-RAO-LIETUVA |      SPH (SOPHARMA)                          SOPHARMA
#      ITB (INTERBUD)                   INTERBUD-LUBLIN |         SPL (SANPL)                               SPL
#       ITX (INDITEX)                               ITX |     SPR (SPYROSOFT)                               SPR
#            IUS (IU)                    INTERNET-UNION |     STF (STALPROFI)                        STALPROFIL
#     IVE (INVESTEKO)                         INVESTEKO |      STP (STALPROD)                       STALPRODUKT
#        IVO (INCUVO)                               IVO |         STS (SATIS)                               STS
#      IWS (IRONWOLF)                               IWS |       STX (STALEXP)             STALEXPORT-AUTOSTRADY
#       IZB (IZOBLOK)                           IZOBLOK |      SVE (SNTVERSE)                               SVE
#      IZO (IZOLACJA)                  IZOLACJA-JAROCIN | SVRS (SILVAIR-REGS)                              SVRS
#       IZS (IZOSTAL)                           IZOSTAL |     SWG (SECOGROUP)                      SECO-WARWICK
#       JJB (JUJUBEE)                               JJB |    TAR (TARCZYNSKI)                        TARCZYNSKI
#      JMT (JERONIMO)                               JMT |         TBL (TBULL)                               TBL
#      JRC (JRCGROUP)                             PYLON |       TEN (TSGAMES)                               TEN
#     JRH (JRHOLDING)                         JR-INVEST |     THG (TENDERHUT)                               THG
#                 JSW    JSW-JASTRZEBSKA-SPOLKA-WEGLOWA |         TLX (TALEX)                             TALEX
#     JWW (JWWINVEST)                        JWW-INVEST |         TMR (TATRY)            TATRY-MOUNTAIN-RESORTS
#     K2H (K2HOLDING)                        K2-HOLDING |          TOA (TOYA)                              TOYA
#     K2P (KOOL2PLAY)                               K2P |        TOR (TORPOL)                            TORPOL
#                 KBJ                               KBJ |     TOW (TOWERINVT)                               TOW
#      KBT (KLABATER)                               KBT |      TPE (TAURONPE)                            TAURON
#      KCH (KRAKCHEM)                        KRAKCHEMIA |        TRI (TRITON)                TRITON-DEVELOPMENT
#                 KCI                               KCI |       TRK (TRAKCJA)                           TRAKCJA
#     KDM (KDMSHIPNG)       KDM-SHIPPING-PUBLIC-LIMITED |      TRN (TRANSPOL)                     TRANS-POLONIA
#        KER (KERNEL)                            KERNEL |      TRR (TERMOREX)                         TERMO-REX
#          KGH (KGHM)                              KGHM |        TSG (TESGAS)                            TESGAS
#                 KGL                               KGL |          TXT (TEXT)                               TXT
#      KGN (KOGENERA)                       KOGENERACJA |     UCG (UNICREDIT)                         UNICREDIT
#          KLN (KLON)                              KLON |      ULG (ULTGAMES)                               ULG
#                 KME                 KANCELARIA-MEDIUS |          ULM (ULMA)                 ULMA-CONSTRUCCION
#        KMP (KOMPAP)                            KOMPAP |        UNF (UNFOLD)                               UNF
#     KOM (KOMPUTRON)                       KOMPUTRONIK |        UNI (UNIBEP)                            UNIBEP
#       KOR (KORBANK)                           KORBANK |     UNL (UNILABGAM)                               UNL
#        KPC (KUPIEC)                            KUPIEC |        UNT (UNIMOT)                        UNIMOT-GAZ
#          KPD (KPPD)                               KPD |       URT (URTESTE)                               URT
#     KPI (KANCELWEC)                               KPI |     VGO (VIGOPHOTN)                               VGO
#       KPL (KINOPOL)                    KINO-POLSKA-TV |      VIN (VINDEXUS)                          VINDEXUS
#      KRI (KREDYTIN)                     KREDYT-INKASO |         VOT (VOTUM)                             VOTUM
#          KRK (KRKA)                              KRKA |         VOX (VOXEL)                             VOXEL
#          KRU (KRUK)                              KRUK |        VRC (VERCOM)                               VRC
#       KSG (KSGAGRO)                          KSG-AGRO |                 VRG                               VRG
#          KTY (KETY)                              KETY |        VTL (VISTAL)                            VISTAL
#        KUB (KUBOTA)                               KUB |         VVD (VIVID)                       VIVID-GAMES
#     KVT (KRVITAMIN)                               KVT |         WAS (WASKO)                             WASKO
#     LAB (LABOPRINT)                        LABO-PRINT |        WIK (WIKANA)                            WIKANA
#     LBD (LOKATYBUD)                  LOKATY-BUDOWLANE |       WIS (WINVEST)                               WIS
#         LBT (LIBET)                             LIBET |       WLT (WIELTON)                           WIELTON
#        LBW (LUBAWA)                            LUBAWA |     WPL (WIRTUALNA)                  WIRTUALNA-POLSKA
#     LCN (LABOCANNA)                               LCN |      WPR (WOODPCKR)                               WPR
#        LEG (LEGIMI)                               LEG |      WTN (WITTCHEN)                               WTN
#          LEN (LENA)                     LENA-LIGHTING |         WWL (WAWEL)                             WAWEL
#          LES (LESS)                               LES |      WXF (WARIMPEX)                          WARIMPEX
#         LET (LETUS)                     LETUS-CAPITAL |         XPL (XPLUS)                             XPLUS
#       LGT (LGTRADE)                               LGT |                 XTB                               XTB
#         LKD (LOKUM)                               LKD |          XTP (XTPL)                               XTP
#       LMG (LMGAMES)                               LMG |        YAN (NEPTIS)                            NEPTIS
#                 LPP                               LPP |          YOL (YOLO)                              YOLO
#     LPS (LAURENPES)                       LAUREN-PESO |         YRL (YARRL)                             YARRL
#          LRK (LARK)                               LRK |         ZAB (ZABKA)                               ZAB
#          LRQ (LARQ)                               LRQ |        ZAP (PULAWY)            ZAKLADY-AZOTOWE-PULAWY
#       LSI (LSISOFT)                      LSI-SOFTWARE |         ZEP (ZEPAK)                             ZEPAK
#       LTM (LTGAMES)                           LTGAMES |         ZMT (ZAMET)                    ZAMET-INDUSTRY
#        LTX (LENTEX)                            LENTEX |         ZRE (ZREMB)                    ZREMB-CHOJNICE
#         LUD (LUDUS)                               LUD |                 ZUE                               ZUE
#                 LUG                               LUG |     ZUK (STAPORKOW)                         STAPORKOW
#       LUK (LUKARDI)                           LUKARDI |     4MB (4MOBILITY)                         4MOBILITY
#      LVC (LIVECHAT)                          LIVECHAT |          7FT (7FIT)                               7FT
#      LWB (BOGDANKA)                          BOGDANKA |       7LV (7LEVELS)                               7LV
#                 M4B                               M4B |     AAS (AALLIANCE)                               AAS
#        MAB (MABION)                            MABION |          ABK (ABAK)                              ABAK
#        MAD (MADKOM)                            MADKOM |        ADX (ADATEX)                               ADX
#     MAK (MAKARONPL)                  MAKARONY-POLSKIE |     AER (AERFINANC)                               AER
#       MAN (MANYDEV)                               MAN |     AFC (AKCEPTFIN)                    AKCEPT-FINANCE
#       MAX (MAXIMUS)                           MAXIMUS |         AFH (AFHOL)                    AFORTI-HOLDING
#      MBF (MBFGROUP)                         MBF-GROUP |      AGL (AGROLIGA)                    AGROLIGA-GROUP
#      MBG (MERCEDES)                               MBG |       AGP (AGROMEP)                           AGROMEP
#         MBK (MBANK)                             MBANK |         AIT (AITON)                    AITON-CALDWELL
#        MBR (MOBRUK)                               MBR |         AME (AMESA)                               AME
#          MBW (MBWS)                               MBW |       AMV (ASMODEV)                               AMV
#      MCD (MYCODERN)                               MCD |       AOL (ANALIZY)                    ANALIZY-ONLINE
#                 MCI                               MCI |        APA (APANET)                            APANET
# ...
#       SEN (SERINUS)                               SEN |       NGG (NGGAMES)                               NGG
#        SES (SESCOM)                            SESCOM |         NOB (NOOBZ)                               NOB
#       SEV (SEVENET)                           SEVENET |        NOV (NOVINA)                            NOVINA
#                 SFD                               SFD |       NRS (NEURONE)                               NRS
#       SFG (SILVANO)                AS-SILVANO-FASHION |     NST (NESTMEDIC)                               NST
#     SFK (SFKPOLKAP)                            POLKAP |       NTS (NOTORIA)                    NOTORIA-SERWIS
#      SFN (SFERANET)                          SFERANET |         NTV (NTVSA)                               NTV
#        SFS (SFINKS)                            SFINKS |          NWA (NWAI)                NWAI-DOM-MAKLERSKI
#       SGN (SYGNITY)                           SYGNITY |      NXB (NEXTBIKE)                               NXB
#      SGR (SADOVAYA)                          SADOVAYA |     O2T (ONE2TRIBE)                               O2T
#       SHD (SOHODEV)                  SOHO-DEVELOPMENT |         OLY (OLYMP)                               OLY
#     SHG (STARHEDGE)                         STARHEDGE |       OML (ONEMORE)                               OML
#        SHO (SHOPER)                               SHO |         ONC (ONICO)                             ONICO
#     SHY (SHEEPYARD)                               SHY |     ONE (1SOLUTION)                               ONE
#       SIE (SIEMENS)                               SIE |       OPI (OPTIGIS)                               OPI
#     SIM (SIMFABRIC)                               SIM |       ORG (ORGANIC)             ORGANIC-FARMA-ZDROWIA
#     SIN (SOLARINOV)                               SIN |     ORL (ORZLOPONY)                             ORZEL
#       SKA (SNIEZKA)                           SNIEZKA |     OUT (OUTDOORZY)                         OUTDOORZY
#      SKH (SKARBIEC)                  SKARBIEC-HOLDING |     OVI (OVIDWORKS)                               OVI
#       SKL (SKYLINE)                SKYLINE-INVESTMENT |        OXY (OXYGEN)                               OXY
#        SKN (SAKANA)                            SAKANA |    OZE (OZECAPITAL)                               OZE
#     SLT (SAULETECH)                               SLT |     P24 (PRESENT24)                         PRESENT24
#       SLV (SELVITA)                               SLV |     P2B (PLANETB2B)                               P2B
#      SLZ (SLEEPZAG)                               SLZ |       P2C (P2CHILL)                               P2C
#     SMT (SIMTERACT)                               SMT |       PAC (PROACTA)                               PAC
#       SNG (SYNERGA)                               SNG |      PBB (PREFABET)                          PREFABET
#         SNK (SANOK)                      STOMIL-SANOK |       PBT (PBGAMES)                               PBT
#      SNT (SYNEKTIK)                          SYNEKTIK |       PDG (PYRAMID)                               PDG
#        SNW (SANWIL)                    SANWIL-HOLDING |      PFG (PREFAGRP)                         PHIWIERZY
#         SNX (SUNEX)                             SUNEX |     PIT (POLARISIT)                               PIT
#         SOK (SONKA)                               SOK |     PIX (PIXELCROW)                               PIX
#         SOL (SOLAR)                     SOLAR-COMPANY |       PLG (PLGROUP)                               PLG
#         SON (SONEL)                             SONEL |       PLI (PLATIGE)                     PLATIGE-IMAGE
#      SPH (SOPHARMA)                          SOPHARMA |        PLM (POLMAN)                            POLMAN
#       SPK (SPARKVC)                           SPARKVC |     PLT (PLOTTWIST)                               PLT
#         SPL (SANPL)                               SPL |         PMG (PGMSA)                               PMG
#     SPR (SPYROSOFT)                               SPR |     PNT (POINTPACK)                               PNT
#      STA (STARWARD)                               STA |     PNW (PLANTWEAR)                               PNW
#      STD (STANDREW)                          STANDREW |     PPG (PUNCHPUNK)                               PPG
#     STF (STALPROFI)                        STALPROFIL |         PRA (PRIME)                               PRA
#    STH (STSHOLDING)                               STH |     PRH (POLHOLROZ)                               PRH
#         STI (STILO)                               STI |       PRN (PARTNER)             PARTNER-NIERUCHOMOSCI
#      STP (STALPROD)                       STALPRODUKT |       PRO (PROMISE)                       APN-PROMISE
#         STS (SATIS)                               STS |        PRS (PRYMUS)                            PRYMUS
#       STX (STALEXP)             STALEXPORT-AUTOSTRADY |     PSH (POLYSLASH)                               PSH
#       SUN (SUNTECH)                           SUNTECH |        PSM (PLASMA)                     PLASMA-SYSTEM
#        SUW (SUWARY)                            SUWARY |     PTE (PARCELTEC)                               PTE
#      SVE (SNTVERSE)                     BIOMED-LUBLIN |     PTN (POLTRONIC)                         POLTRONIC
# SVRS (SILVAIR-REGS)                              SVRS |     QNA (QNATECHNO)                               QNA
#     SWG (SECOGROUP)                      SECO-WARWICK |     QON (QUARTICON)                               QON
#       SWT (SWALLET)                               SWT |         QRT (QUART)                 QUART-DEVELOPMENT
#        SYG (SYGNIS)                               SYG |      QUB (QUBICGMS)                          QUBICGMS
#          SZR (SZAR)                              SZAR |      RBS (ROBINSON)                   ROBINSON-EUROPE
#     T2P (TERMO2PWR)                         TERMO2PWR |         RCA (ROCCA)                             ROCCA
#    TAR (TARCZYNSKI)                        TARCZYNSKI |     RCM (REDCARPET)                               RCM
#         TBL (TBULL)                               TBL |     RCW (RUCHCHORZ)                      RUCH-CHORZOW
#       TEN (TSGAMES)                               TEN |      RDG (READGENE)                         READ-GENE
#        TGG (TRIGGO)                               TGG |     RGL (ROBSGROUP)                         ROBSGROUP
#        TGS (TRUEGS)                               TGS |       RNT (PRIVRNT)                               RNT
#       THD (THEDUST)                               THD |      RRH (RRHGROUP)                               RRH
#     THG (TENDERHUT)                               THG |       RSG (RSGAMES)                               RSG
#                 TIM                               TIM |      RSP (REMORSOL)                               RSP
#        TLG (TELGAM)                            TELGAM |          RST (ROAD)                               RST
#       TLO (TELESTO)                           TELESTO |                 S4E                               S4E
#       TLS (TELESTR)                        TELESTRADA |      SBE (SOFTBLUE)                          SOFTBLUE
#         TLX (TALEX)                             TALEX |     SCS (STEMCELLS)                   STEM-CELLS-SPIN
#      TME (TERMOEXP)                       TERMOEXPERT |       SCW (SCANWAY)                               SCW
#     TMP (TELEMEDPL)                      TELEMEDYCYNA |     SDG (SUNDRAGON)                               SDG
#         TMR (TATRY)            TATRY-MOUNTAIN-RESORTS |      SDS (SDSOPTIC)                               SDS
#          TOA (TOYA)                              TOYA |       SED (SEDIVIO)                               SED
#        TOR (TORPOL)                            TORPOL |       SEV (SEVENET)                           SEVENET
#         TOS (TAMEX)                             TAMEX |                 SFD                               SFD
#     TOW (TOWERINVT)                               TOW |     SFK (SFKPOLKAP)                            POLKAP
#      TPE (TAURONPE)                            TAURON |     SHY (SHEEPYARD)                               SHY
#        TRI (TRITON)                TRITON-DEVELOPMENT |     SIN (SOLARINOV)                               SIN
#       TRK (TRAKCJA)                           TRAKCJA |        SKN (SAKANA)                            SAKANA
#      TRN (TRANSPOL)                     TRANS-POLONIA |     SLT (SAULETECH)                               SLT
#      TRR (TERMOREX)                         TERMO-REX |     SMT (SIMTERACT)                               SMT
#        TSG (TESGAS)                            TESGAS |       SNG (SYNERGA)                               SNG
#        TXN (TAXNET)                           TAX-NET |        SNN (SUNNET)                               SNN
#         U2K (UNIMA)                        UNIMA-2000 |         SOK (SONKA)                               SOK
#     UCG (UNICREDIT)                         UNICREDIT |      STA (STARWARD)                               STA
#       UFC (UNIFIED)                               UFC |      STD (STANDREW)                          STANDREW
#       UFG (UFGAMES)                               UFG |         STI (STILO)                               STI
#      ULG (ULTGAMES)                               ULG |       SUN (SUNTECH)                           SUNTECH
#          ULM (ULMA)                 ULMA-CONSTRUCCION |     SWM (SWMANSION)                               SWM
#        UNF (UNFOLD)                               UNF |        SYG (SYGNIS)                               SYG
#        UNI (UNIBEP)                            UNIBEP |          SZR (SZAR)                              SZAR
#     UNL (UNILABGAM)                               UNL |     T2P (TERMO2PWR)                         TERMO2PWR
#        UNT (UNIMOT)                        UNIMOT-GAZ |        TGG (TRIGGO)                               TGG
#      UNV (UNIVERSE)                              ALDA |        TGS (TRUEGS)                               TGS
#       URT (URTESTE)                               URT |       THD (THEDUST)                               THD
#        VAR (VARSAV)                               VAR |        TLG (TELGAM)                            TELGAM
#         VDS (VIDIS)                             VIDIS |       TLO (TELESTO)                           TELESTO
#                 VEE                               VEE |       TLS (TELESTR)                        TELESTRADA
#     VER (MPLVERBUM)                        MPL-VERBUM |      TME (TERMOEXP)                       TERMOEXPERT
#      VFA (VRFABRIC)                               VFA |     TMP (TELEMEDPL)                      TELEMEDYCYNA
#     VGO (VIGOPHOTN)                               VGO |     TNT (TNTPROENR)                               TNT
#       VIA (VIATRON)                           VIATRON |         TOS (TAMEX)                             TAMEX
#      VIN (VINDEXUS)                          VINDEXUS |          TRX (TREX)                               TRX
#        VIV (VISION)                    VIRTUAL-VISION |        TXN (TAXNET)                           TAX-NET
#      VKT (VAKOMTEK)                          VAKOMTEK |       UFC (UNIFIED)                               UFC
#         VLT (VOOLT)                               VLT |       UFG (UFGAMES)                               UFG
#         VOT (VOTUM)                             VOTUM |      UNV (UNIVERSE)                              ALDA
#    VOW (VOLKSWAGEN)                               VOW |        VAR (VARSAV)                               VAR
#         VOX (VOXEL)                             VOXEL |         VDS (VIDIS)                             VIDIS
#      VRB (VERBICOM)                          VERBICOM |                 VEE                               VEE
#        VRC (VERCOM)                               VRC |     VER (MPLVERBUM)                        MPL-VERBUM
#     VRF (VRFACTORY)                               VRF |      VFA (VRFABRIC)                               VFA
#                 VRG                               VRG |        VIV (VISION)                    VIRTUAL-VISION
#        VTL (VISTAL)                            VISTAL |      VKT (VAKOMTEK)                          VAKOMTEK
#         VVD (VIVID)                       VIVID-GAMES |         VLT (VOOLT)                               VLT
#         WAS (WASKO)                             WASKO |        VMX (VMAXSA)                               VMX
#                 WAT                               WAT |      VRB (VERBICOM)                          VERBICOM
#     WHH (WERTHHOLZ)                        WERTH-HOLZ |     VRF (VRFACTORY)                               VRF
#        WIK (WIKANA)                            WIKANA |     WGP (WGPARTNER)                               WGP
#       WIS (WINVEST)                               WIS |     WHH (WERTHHOLZ)                        WERTH-HOLZ
#       WLT (WIELTON)                           WIELTON |        WOD (WODKAN)                            WODKAN
#        WOD (WODKAN)                            WODKAN |      WRE (WESTREAL)                  WEST-REAL-ESTATE
#         WOJ (WOJAS)                             WOJAS |      WRL (WIERZYCL)                        WIERZYCIEL
#     WPL (WIRTUALNA)                  WIRTUALNA-POLSKA |     XBS (XBSPROLOG)                               XBS
#      WPR (WOODPCKR)                               WPR |       XDD (MENTZEN)                               XDD
#      WRE (WESTREAL)                  WEST-REAL-ESTATE |     YBS (YELLOWBOS)                               YBS
#      WRL (WIERZYCL)                        WIERZYCIEL |         YOS (YOSHI)                               YOS
#      WTN (WITTCHEN)                               WTN |     YTF (YETIFORCE)                               YTF
#         WWL (WAWEL)                             WAWEL |       ZEN (ZENERIS)                               ZEN
#      WXF (WARIMPEX)                          WARIMPEX |       ZRX (ZORTRAX)                               ZRX
#     XBS (XBSPROLOG)                               XBS |                 NaN                               NaN
#         XPL (XPLUS)                             XPLUS |                 NaN                               NaN
#                 XTB                               XTB |                 NaN                               NaN
#          XTP (XTPL)                               XTP |                 NaN                               NaN
#        YAN (NEPTIS)                            NEPTIS |                 NaN                               NaN
#     YBS (YELLOWBOS)                               YBS |                 NaN                               NaN
#          YOL (YOLO)                              YOLO |                 NaN                               NaN
#         YOS (YOSHI)                               YOS |                 NaN                               NaN
#     YTF (YETIFORCE)                               YTF |                 NaN                               NaN
#       ZAL (ZALANDO)                               ZAL |                 NaN                               NaN
#        ZAP (PULAWY)            ZAKLADY-AZOTOWE-PULAWY |                 NaN                               NaN
#       ZEN (ZENERIS)                               ZEN |                 NaN                               NaN
#         ZEP (ZEPAK)                             ZEPAK |                 NaN                               NaN
#         ZMT (ZAMET)                    ZAMET-INDUSTRY |                 NaN                               NaN
#         ZRE (ZREMB)                    ZREMB-CHOJNICE |                 NaN                               NaN
#       ZRX (ZORTRAX)                               ZRX |                 NaN                               NaN
#                 ZUE                               ZUE |                 NaN                               NaN
#     ZUK (STAPORKOW)                         STAPORKOW |                 NaN                               NaN
